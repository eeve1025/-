# %%
import openpyxl
#抓取"104有關大數據工作"相關資料--作品1
import requests
import bs4

res=requests.get('https://www.104.com.tw/jobs/search/?ro=0&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=1&asc=0&page=1&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1')
soup=bs4.BeautifulSoup(res.text)

wb=openpyxl.Workbook()
ws=wb.active

ws['A1']='職缺名稱'
ws['B1']='職缺連結'
ws['C1']='公司名稱'
ws['D1']='工作地區'
ws['E1']='薪資待遇'

page=1
while soup.find_all('article',class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
  print("=======================")
  print("現在正在讀取第",page,"頁")
  print("=======================")

  for job in soup.find_all('article',class_="b-block--top-bord job-list-item b-clearfix js-job-item"):

    a=job.a.text
    b='http:'+job.a['href']
    c=job.ul.a.text.strip()
    d=job.select('ul')[1].li.text
    if  job.find('div',class_="job-list-tag b-content").select('span')!=[] and job.find('div',class_="job-list-tag b-content").span.text=="待遇面議":
        e=job.find('div',class_="job-list-tag b-content").span.text
    else:
        e=job.find('div',class_="job-list-tag b-content").a.text
    ws.append([a,b,c,d,e])
  page+=1
  res=requests.get('https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=12&asc=0&page='+str(page)+'&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1')
  soup=bs4.BeautifulSoup(res.text)
  

wb.save("104大數據職缺清單.xlsx")
# Out:
# =======================
# 現在正在讀取第 1 頁
# =======================
# =======================
# 現在正在讀取第 2 頁
# =======================
# =======================
# 現在正在讀取第 3 頁
# =======================
# =======================
# 現在正在讀取第 4 頁
# =======================
# =======================
# 現在正在讀取第 5 頁
# =======================
# =======================
# 現在正在讀取第 6 頁
# =======================
# =======================
# 現在正在讀取第 7 頁
# =======================
# =======================
# 現在正在讀取第 8 頁
# =======================
# =======================
# 現在正在讀取第 9 頁
# =======================
# =======================
# 現在正在讀取第 10 頁
# =======================
# =======================
# 現在正在讀取第 11 頁
# =======================
# =======================
# 現在正在讀取第 12 頁
# =======================
# =======================
# 現在正在讀取第 13 頁
# =======================
# =======================
# 現在正在讀取第 14 頁
# =======================
# =======================
# 現在正在讀取第 15 頁
# =======================
# =======================
# 現在正在讀取第 16 頁
# =======================
# =======================
# 現在正在讀取第 17 頁
# =======================
# =======================
# 現在正在讀取第 18 頁
# =======================
# =======================
# 現在正在讀取第 19 頁
# =======================
# =======================
# 現在正在讀取第 20 頁
# =======================
# =======================
# 現在正在讀取第 21 頁
# =======================
# =======================
# 現在正在讀取第 22 頁
# =======================
# =======================
# 現在正在讀取第 23 頁
# =======================
# =======================
# 現在正在讀取第 24 頁
# =======================
# =======================
# 現在正在讀取第 25 頁
# =======================
# =======================
# 現在正在讀取第 26 頁
# =======================
# =======================
# 現在正在讀取第 27 頁
# =======================
# =======================
# 現在正在讀取第 28 頁
# =======================
# =======================
# 現在正在讀取第 29 頁
# =======================
# =======================
# 現在正在讀取第 30 頁
# =======================
# =======================
# 現在正在讀取第 31 頁
# =======================
# =======================
# 現在正在讀取第 32 頁
# =======================
# =======================
# 現在正在讀取第 33 頁
# =======================
# =======================
# 現在正在讀取第 34 頁
# =======================
# =======================
# 現在正在讀取第 35 頁
# =======================
# =======================
# 現在正在讀取第 36 頁
# =======================
# =======================
# 現在正在讀取第 37 頁
# =======================
# =======================
# 現在正在讀取第 38 頁
# =======================
# =======================
# 現在正在讀取第 39 頁
# =======================
# =======================
# 現在正在讀取第 40 頁
# =======================
# =======================
# 現在正在讀取第 41 頁
# =======================
# =======================
# 現在正在讀取第 42 頁
# =======================
# =======================
# 現在正在讀取第 43 頁
# =======================
# =======================
# 現在正在讀取第 44 頁
# =======================
# =======================
# 現在正在讀取第 45 頁
# =======================
# =======================
# 現在正在讀取第 46 頁
# =======================
# =======================
# 現在正在讀取第 47 頁
# =======================
# =======================
# 現在正在讀取第 48 頁
# =======================
# =======================
# 現在正在讀取第 49 頁
# =======================
# =======================
# 現在正在讀取第 50 頁
# =======================
# =======================
# 現在正在讀取第 51 頁
# =======================
# =======================
# 現在正在讀取第 52 頁
# =======================
# =======================
# 現在正在讀取第 53 頁
# =======================
# =======================
# 現在正在讀取第 54 頁
# =======================
# =======================
# 現在正在讀取第 55 頁
# =======================
# =======================
# 現在正在讀取第 56 頁
# =======================
# =======================
# 現在正在讀取第 57 頁
# =======================
# =======================
# 現在正在讀取第 58 頁
# =======================
# =======================
# 現在正在讀取第 59 頁
# =======================
# =======================
# 現在正在讀取第 60 頁
# =======================
# =======================
# 現在正在讀取第 61 頁
# =======================
# =======================
# 現在正在讀取第 62 頁
# =======================
# =======================
# 現在正在讀取第 63 頁
# =======================
# =======================
# 現在正在讀取第 64 頁
# =======================
# =======================
# 現在正在讀取第 65 頁
# =======================
# =======================
# 現在正在讀取第 66 頁
# =======================
# =======================
# 現在正在讀取第 67 頁
# =======================
# =======================
# 現在正在讀取第 68 頁
# =======================
# =======================
# 現在正在讀取第 69 頁
# =======================
# =======================
# 現在正在讀取第 70 頁
# =======================
# =======================
# 現在正在讀取第 71 頁
# =======================
# =======================
# 現在正在讀取第 72 頁
# =======================
# =======================
# 現在正在讀取第 73 頁
# =======================
# =======================
# 現在正在讀取第 74 頁
# =======================
# =======================
# 現在正在讀取第 75 頁
# =======================
# =======================
# 現在正在讀取第 76 頁
# =======================
# =======================
# 現在正在讀取第 77 頁
# =======================
# =======================
# 現在正在讀取第 78 頁
# =======================
# =======================
# 現在正在讀取第 79 頁
# =======================
# =======================
# 現在正在讀取第 80 頁
# =======================
# =======================
# 現在正在讀取第 81 頁
# =======================
# =======================
# 現在正在讀取第 82 頁
# =======================
# =======================
# 現在正在讀取第 83 頁
# =======================
# =======================
# 現在正在讀取第 84 頁
# =======================
# =======================
# 現在正在讀取第 85 頁
# =======================
# =======================
# 現在正在讀取第 86 頁
# =======================
# =======================
# 現在正在讀取第 87 頁
# =======================
# =======================
# 現在正在讀取第 88 頁
# =======================
# =======================
# 現在正在讀取第 89 頁
# =======================
# =======================
# 現在正在讀取第 90 頁
# =======================
# =======================
# 現在正在讀取第 91 頁
# =======================
# =======================
# 現在正在讀取第 92 頁
# =======================
# =======================
# 現在正在讀取第 93 頁
# =======================
# =======================
# 現在正在讀取第 94 頁
# =======================
# =======================
# 現在正在讀取第 95 頁
# =======================
# =======================
# 現在正在讀取第 96 頁
# =======================
# =======================
# 現在正在讀取第 97 頁
# =======================
# =======================
# 現在正在讀取第 98 頁
# =======================
# =======================
# 現在正在讀取第 99 頁
# =======================
# =======================
# 現在正在讀取第 100 頁
# =======================
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[10], line 34
#      32   else:
#      33       e=job.find('div',class_="job-list-tag b-content").a.text
# ---> 34   ws.append([a,b,c,d,e])
#      35 page+=1
#      36 res=requests.get('https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=12&asc=0&page='+str(page)+'&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1')
#
# File ~/.python/current/lib/python3.10/site-packages/openpyxl/worksheet/worksheet.py:670, in Worksheet.append(self, iterable)
#     668             cell.row = row_idx
#     669         else:
# --> 670             cell = Cell(self, row=row_idx, column=col_idx, value=content)
#     671         self._cells[(row_idx, col_idx)] = cell
#     673 elif isinstance(iterable, dict):
#
# File ~/.python/current/lib/python3.10/site-packages/openpyxl/cell/cell.py:119, in Cell.__init__(self, worksheet, row, column, value, style_array)
#     117 self.data_type = 'n'
#     118 if value is not None:
# --> 119     self.value = value
#     120 self._comment = None
#
# File ~/.python/current/lib/python3.10/site-packages/openpyxl/cell/cell.py:218, in Cell.value(self, value)
#     215 @value.setter
#     216 def value(self, value):
#     217     """Set the value and infer type and display options."""
# --> 218     self._bind_value(value)
#
# File ~/.python/current/lib/python3.10/site-packages/openpyxl/cell/cell.py:197, in Cell._bind_value(self, value)
#     194         self.number_format = get_time_format(t)
#     196 elif dt == "s" and not isinstance(value, CellRichText):
# --> 197     value = self.check_string(value)
#     198     if len(value) > 1 and value.startswith("="):
#     199         self.data_type = 'f'
#
# File ~/.python/current/lib/python3.10/site-packages/openpyxl/cell/cell.py:165, in Cell.check_string(self, value)
#     163 value = value[:32767]
#     164 if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 165     raise IllegalCharacterError(f"{value} cannot be used in worksheets.")
#     166 return value
#
#  cannot be used in worksheets.
